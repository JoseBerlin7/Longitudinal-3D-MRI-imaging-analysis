# %% [markdown]
# # Multi-modal MRI Analysis
# Goal : To understand data -> clean & Preprocess CSV data -> clean & preprocess MRI data  -> adapt a 3D model to predict deformation fields

# %%
# !ls
# Out:
# data  understand_data.ipynb  understand_data.ipynb.amltmp

# %%
# %cd projects/'MRI analysis'/
# Out:
# [Errno 2] No such file or directory: 'projects/MRI analysis/'
# /mnt/batch/tasks/shared/LS_root/mounts/clusters/e4ds-v4/code/projects/MRI analysis

# %% [markdown]
# ### Mounting data

# %%
from azureml.core import Workspace, Datastore
from azureml.data.dataset_factory import FileDatasetFactory

import os
import pandas as pd
import nibabel as nib

# %%
ws = Workspace.from_config()
ds = Datastore.get(ws, datastore_name='cvdatastore')
dataset = FileDatasetFactory.from_files(path=(ds, 'Oasis/'), validate=False)
mount_path = dataset.mount()
mount_path.start()
print("Dataset mounted at: ", mount_path.mount_point)
# Out:
# Dataset mounted at:  /tmp/tmpm1m1z_ux

# %%
os.listdir(mount_path.mount_point)
# Out:
# ['OAS2_RAW_PART1', 'OAS2_RAW_PART2']

# %%
df = pd.read_csv(
    os.path.join("data", 'oasis_longitudinal_demographics.csv')
    )

# %% [markdown]
# ### Data Analysis

# %% [markdown]
# #### CSV

# %%
len(df)
# Out:
# 373

# %%
df.head()
# Out:
#   Subject ID         MRI ID        Group  Visit  MR Delay M/F Hand  Age  EDUC  \
# 0  OAS2_0001  OAS2_0001_MR1  Nondemented      1         0   M    R   87    14
# 1  OAS2_0001  OAS2_0001_MR2  Nondemented      2       457   M    R   88    14
# 2  OAS2_0002  OAS2_0002_MR1     Demented      1         0   M    R   75    12
# 3  OAS2_0002  OAS2_0002_MR2     Demented      2       560   M    R   76    12
# 4  OAS2_0002  OAS2_0002_MR3     Demented      3      1895   M    R   80    12
#
#    SES  MMSE  CDR  eTIV   nWBV    ASF
# 0  2.0  27.0  0.0  1987  0.696  0.883
# 1  2.0  30.0  0.0  2004  0.681  0.876
# 2  NaN  23.0  0.5  1678  0.736  1.046
# 3  NaN  28.0  0.5  1738  0.713  1.010
# 4  NaN  22.0  0.5  1698  0.701  1.034

# %%
df['Group'].value_counts()
# Out:
# Group
# Nondemented    190
# Demented       146
# Converted       37
# Name: count, dtype: int64

# %%
print("Visit counts:")
df['Visit'].value_counts()
# Out:
# Visit counts:
# Visit
# 1    150
# 2    144
# 3     58
# 4     15
# 5      6
# Name: count, dtype: int64

# %% [markdown]
# UNDERSTANIDING of DATA
#
# So we have 373 entries, same subject Id having multiple visits (not all).
# > 150 patients had visit 1
#
# > 144 patients had vsisit 2
#
# > 58 patients had visit 3
#
# > 15 patients had visit 4
#
# > 6 patients had visit 5
#
# we only need the patients that had more than 1 visit for longitudinal imaging registration. Maybe also only consider who are diagonesed ("Demented" and "Converted")

# %% [markdown]
# ##### Data cleaning & filtering

# %%
subject_IDs = []
for subj, grp in df.groupby('Subject ID'):
    if grp["Visit"].max() > 1:
        subject_IDs.append(subj)
len(subject_IDs)
# Out:
# 150

# %% [markdown]
# As we see here, all of the patients have more than one MRI taken. i.e., all of the patients has more than 1 visit.
# that means, the data doesn't have all of the visit's MRI.
#
# So we will narrow it down to Subjects only diagoned

# %%
subjects = []

for subj_id, group_df in df.groupby('Subject ID'):
    if (group_df["Group"].isin(['Demented', 'Converted']).any()):
        subjects.append(subj_id)

len(subjects)
# Out:
# 78

# %% [markdown]
# among 150 subjects 78 subjects has been diagnosed.
# will be using all the 150 subjects for the strain map detection.

# %% [markdown]
# #### including MRI paths with CSV

# %%
paths = []
for dir in os.listdir(mount_path.mount_point):
    data_path = os.path.join(mount_path.mount_point, dir)
    print("subdir:",len(os.listdir(data_path)))
    for sub_dir in os.listdir(data_path):
        fin_path=os.path.join(data_path, sub_dir, "RAW")
        if os.path.exists(fin_path):
            paths.append(fin_path)
        else:
            print("Path does not exist:", fin_path)
print("Total MRIs: ", len(paths))
# Out:
# subdir: 209
# subdir: 164
# Total MRIs:  373

# %%
paths[:5]
# Out:
# ['/tmp/tmpm1m1z_ux/OAS2_RAW_PART1/OAS2_0001_MR1/RAW',
#  '/tmp/tmpm1m1z_ux/OAS2_RAW_PART1/OAS2_0001_MR2/RAW',
#  '/tmp/tmpm1m1z_ux/OAS2_RAW_PART1/OAS2_0002_MR1/RAW',
#  '/tmp/tmpm1m1z_ux/OAS2_RAW_PART1/OAS2_0002_MR2/RAW',
#  '/tmp/tmpm1m1z_ux/OAS2_RAW_PART1/OAS2_0002_MR3/RAW']

# %%
# we can pinpoint one example path for a subject ID using the following method
subject_IDs[0] in paths[1]
# Out:
# True

# %%
paths[0]
# Out:
# '/tmp/tmpm1m1z_ux/OAS2_RAW_PART1/OAS2_0001_MR1/RAW'

# %%
# structuring the data for easier access later
data_dict = {}
for path in paths:
    parts = path.split(os.sep)
    subj_id = parts[-2][:9]
    visit_num = parts[-2][-1]
    if subj_id not in data_dict:
        data_dict[subj_id] = {}
    data_dict[subj_id][visit_num] = path

# %%
data_dict
# Out:
# {'OAS2_0001': {'1': '/tmp/tmpm1m1z_ux/OAS2_RAW_PART1/OAS2_0001_MR1/RAW',
#   '2': '/tmp/tmpm1m1z_ux/OAS2_RAW_PART1/OAS2_0001_MR2/RAW'},
#  'OAS2_0002': {'1': '/tmp/tmpm1m1z_ux/OAS2_RAW_PART1/OAS2_0002_MR1/RAW',
#   '2': '/tmp/tmpm1m1z_ux/OAS2_RAW_PART1/OAS2_0002_MR2/RAW',
#   '3': '/tmp/tmpm1m1z_ux/OAS2_RAW_PART1/OAS2_0002_MR3/RAW'},
#  'OAS2_0004': {'1': '/tmp/tmpm1m1z_ux/OAS2_RAW_PART1/OAS2_0004_MR1/RAW',
#   '2': '/tmp/tmpm1m1z_ux/OAS2_RAW_PART1/OAS2_0004_MR2/RAW'},
#  'OAS2_0005': {'1': '/tmp/tmpm1m1z_ux/OAS2_RAW_PART1/OAS2_0005_MR1/RAW',
#   '2': '/tmp/tmpm1m1z_ux/OAS2_RAW_PART1/OAS2_0005_MR2/RAW',
#   '3': '/tmp/tmpm1m1z_ux/OAS2_RAW_PART1/OAS2_0005_MR3/RAW'},
#  'OAS2_0007': {'1': '/tmp/tmpm1m1z_ux/OAS2_RAW_PART1/OAS2_0007_MR1/RAW',
#   '3': '/tmp/tmpm1m1z_ux/OAS2_RAW_PART1/OAS2_0007_MR3/RAW',
#   '4': '/tmp/tmpm1m1z_ux/OAS2_RAW_PART1/OAS2_0007_MR4/RAW'},
#  'OAS2_0008': {'1': '/tmp/tmpm1m1z_ux/OAS2_RAW_PART1/OAS2_0008_MR1/RAW',
#   '2': '/tmp/tmpm1m1z_ux/OAS2_RAW_PART1/OAS2_0008_MR2/RAW'},
#  'OAS2_0009': {'1': '/tmp/tmpm1m1z_ux/OAS2_RAW_PART1/OAS2_0009_MR1/RAW',
#   '2': '/tmp/tmpm1m1z_ux/OAS2_RAW_PART1/OAS2_0009_MR2/RAW'},
#  'OAS2_0010': {'1': '/tmp/tmpm1m1z_ux/OAS2_RAW_PART1/OAS2_0010_MR1/RAW',
#   '2': '/tmp/tmpm1m1z_ux/OAS2_RAW_PART1/OAS2_0010_MR2/RAW'},
#  'OAS2_0012': {'1': '/tmp/tmpm1m1z_ux/OAS2_RAW_PART1/OAS2_0012_MR1/RAW',
#   '2': '/tmp/tmpm1m1z_ux/OAS2_RAW_PART1/OAS2_0012_MR2/RAW',
#   '3': '/tmp/tmpm1m1z_ux/OAS2_RAW_PART1/OAS2_0012_MR3/RAW'},
#  'OAS2_0013': {'1': '/tmp/tmpm1m1z_ux/OAS2_RAW_PART1/OAS2_0013_MR1/RAW',
#   '2': '/tmp/tmpm1m1z_ux/OAS2_RAW_PART1/OAS2_0013_MR2/RAW',
#   '3': '/tmp/tmpm1m1z_ux/OAS2_RAW_PART1/OAS2_0013_MR3/RAW'},
#  'OAS2_0014': {'1': '/tmp/tmpm1m1z_ux/OAS2_RAW_PART1/OAS2_0014_MR1/RAW',
#   '2': '/tmp/tmpm1m1z_ux/OAS2_RAW_PART1/OAS2_0014_MR2/RAW'},
#  'OAS2_0016': {'1': '/tmp/tmpm1m1z_ux/OAS2_RAW_PART1/OAS2_0016_MR1/RAW',
#   '2': '/tmp/tmpm1m1z_ux/OAS2_RAW_PART1/OAS2_0016_MR2/RAW'},
#  'OAS2_0017': {'1': '/tmp/tmpm1m1z_ux/OAS2_RAW_PART1/OAS2_0017_MR1/RAW',
#   '3': '/tmp/tmpm1m1z_ux/OAS2_RAW_PART1/OAS2_0017_MR3/RAW',
#   '4': '/tmp/tmpm1m1z_ux/OAS2_RAW_PART1/OAS2_0017_MR4/RAW',
#   '5': '/tmp/tmpm1m1z_ux/OAS2_RAW_PART1/OAS2_0017_MR5/RAW'},
#  'OAS2_0018': {'1': '/tmp/tmpm1m1z_ux/OAS2_RAW_PART1/OAS2_0018_MR1/RAW',
#   '3': '/tmp/tmpm1m1z_ux/OAS2_RAW_PART1/OAS2_0018_MR3/RAW',
#   '4': '/tmp/tmpm1m1z_ux/OAS2_RAW_PART1/OAS2_0018_MR4/RAW'},
#  'OAS2_0020': {'1': '/tmp/tmpm1m1z_ux/OAS2_RAW_PART1/OAS2_0020_MR1/RAW',
#   '2': '/tmp/tmpm1m1z_ux/OAS2_RAW_PART1/OAS2_0020_MR2/RAW',
#   '3': '/tmp/tmpm1m1z_ux/OAS2_RAW_PART1/OAS2_0020_MR3/RAW'},
#  'OAS2_0021': {'1': '/tmp/tmpm1m1z_ux/OAS2_RAW_PART1/OAS2_0021_MR1/RAW',
#   '2': '/tmp/tmpm1m1z_ux/OAS2_RAW_PART1/OAS2_0021_MR2/RAW'},
#  'OAS2_0022': {'1': '/tmp/tmpm1m1z_ux/OAS2_RAW_PART1/OAS2_0022_MR1/RAW',
#   '2': '/tmp/tmpm1m1z_ux/OAS2_RAW_PART1/OAS2_0022_MR2/RAW'},
#  'OAS2_0023': {'1': '/tmp/tmpm1m1z_ux/OAS2_RAW_PART1/OAS2_0023_MR1/RAW',
#   '2': '/tmp/tmpm1m1z_ux/OAS2_RAW_PART1/OAS2_0023_MR2/RAW'},
#  'OAS2_0026': {'1': '/tmp/tmpm1m1z_ux/OAS2_RAW_PART1/OAS2_0026_MR1/RAW',
#   '2': '/tmp/tmpm1m1z_ux/OAS2_RAW_PART1/OAS2_0026_MR2/RAW'},
#  'OAS2_0027': {'1': '/tmp/tmpm1m1z_ux/OAS2_RAW_PART1/OAS2_0027_MR1/RAW',
#   '2': '/tmp/tmpm1m1z_ux/OAS2_RAW_PART1/OAS2_0027_MR2/RAW',
#   '3': '/tmp/tmpm1m1z_ux/OAS2_RAW_PART1/OAS2_0027_MR3/RAW',
#   '4': '/tmp/tmpm1m1z_ux/OAS2_RAW_PART1/OAS2_0027_MR4/RAW'},
#  'OAS2_0028': {'1': '/tmp/tmpm1m1z_ux/OAS2_RAW_PART1/OAS2_0028_MR1/RAW',
#   '2': '/tmp/tmpm1m1z_ux/OAS2_RAW_PART1/OAS2_0028_MR2/RAW'},
#  'OAS2_0029': {'1': '/tmp/tmpm1m1z_ux/OAS2_RAW_PART1/OAS2_0029_MR1/RAW',
#   '2': '/tmp/tmpm1m1z_ux/OAS2_RAW_PART1/OAS2_0029_MR2/RAW'},
#  'OAS2_0030': {'1': '/tmp/tmpm1m1z_ux/OAS2_RAW_PART1/OAS2_0030_MR1/RAW',
#   '2': '/tmp/tmpm1m1z_ux/OAS2_RAW_PART1/OAS2_0030_MR2/RAW'},
#  'OAS2_0031': {'1': '/tmp/tmpm1m1z_ux/OAS2_RAW_PART1/OAS2_0031_MR1/RAW',
#   '2': '/tmp/tmpm1m1z_ux/OAS2_RAW_PART1/OAS2_0031_MR2/RAW',
#   '3': '/tmp/tmpm1m1z_ux/OAS2_RAW_PART1/OAS2_0031_MR3/RAW'},
#  'OAS2_0032': {'1': '/tmp/tmpm1m1z_ux/OAS2_RAW_PART1/OAS2_0032_MR1/RAW',
#   '2': '/tmp/tmpm1m1z_ux/OAS2_RAW_PART1/OAS2_0032_MR2/RAW'},
#  'OAS2_0034': {'1': '/tmp/tmpm1m1z_ux/OAS2_RAW_PART1/OAS2_0034_MR1/RAW',
#   '2': '/tmp/tmpm1m1z_ux/OAS2_RAW_PART1/OAS2_0034_MR2/RAW',
#   '3': '/tmp/tmpm1m1z_ux/OAS2_RAW_PART1/OAS2_0034_MR3/RAW',
#   '4': '/tmp/tmpm1m1z_ux/OAS2_RAW_PART1/OAS2_0034_MR4/RAW'},
#  'OAS2_0035': {'1': '/tmp/tmpm1m1z_ux/OAS2_RAW_PART1/OAS2_0035_MR1/RAW',
#   '2': '/tmp/tmpm1m1z_ux/OAS2_RAW_PART1/OAS2_0035_MR2/RAW'},
#  'OAS2_0036': {'1': '/tmp/tmpm1m1z_ux/OAS2_RAW_PART1/OAS2_0036_MR1/RAW',
#   '3': '/tmp/tmpm1m1z_ux/OAS2_RAW_PART1/OAS2_0036_MR3/RAW',
#   '4': '/tmp/tmpm1m1z_ux/OAS2_RAW_PART1/OAS2_0036_MR4/RAW',
#   '5': '/tmp/tmpm1m1z_ux/OAS2_RAW_PART1/OAS2_0036_MR5/RAW'},
#  'OAS2_0037': {'1': '/tmp/tmpm1m1z_ux/OAS2_RAW_PART1/OAS2_0037_MR1/RAW',
#   '2': '/tmp/tmpm1m1z_ux/OAS2_RAW_PART1/OAS2_0037_MR2/RAW',
#   '3': '/tmp/tmpm1m1z_ux/OAS2_RAW_PART1/OAS2_0037_MR3/RAW',
#   '4': '/tmp/tmpm1m1z_ux/OAS2_RAW_PART1/OAS2_0037_MR4/RAW'},
#  'OAS2_0039': {'1': '/tmp/tmpm1m1z_ux/OAS2_RAW_PART1/OAS2_0039_MR1/RAW',
#   '2': '/tmp/tmpm1m1z_ux/OAS2_RAW_PART1/OAS2_0039_MR2/RAW'},
#  'OAS2_0040': {'1': '/tmp/tmpm1m1z_ux/OAS2_RAW_PART1/OAS2_0040_MR1/RAW',
#   '2': '/tmp/tmpm1m1z_ux/OAS2_RAW_PART1/OAS2_0040_MR2/RAW',
#   '3': '/tmp/tmpm1m1z_ux/OAS2_RAW_PART1/OAS2_0040_MR3/RAW'},
#  'OAS2_0041': {'1': '/tmp/tmpm1m1z_ux/OAS2_RAW_PART1/OAS2_0041_MR1/RAW',
#   '2': '/tmp/tmpm1m1z_ux/OAS2_RAW_PART1/OAS2_0041_MR2/RAW',
#   '3': '/tmp/tmpm1m1z_ux/OAS2_RAW_PART1/OAS2_0041_MR3/RAW'},
#  'OAS2_0042': {'1': '/tmp/tmpm1m1z_ux/OAS2_RAW_PART1/OAS2_0042_MR1/RAW',
#   '2': '/tmp/tmpm1m1z_ux/OAS2_RAW_PART1/OAS2_0042_MR2/RAW'},
#  'OAS2_0043': {'1': '/tmp/tmpm1m1z_ux/OAS2_RAW_PART1/OAS2_0043_MR1/RAW',
#   '2': '/tmp/tmpm1m1z_ux/OAS2_RAW_PART1/OAS2_0043_MR2/RAW'},
#  'OAS2_0044': {'1': '/tmp/tmpm1m1z_ux/OAS2_RAW_PART1/OAS2_0044_MR1/RAW',
#   '2': '/tmp/tmpm1m1z_ux/OAS2_RAW_PART1/OAS2_0044_MR2/RAW',
#   '3': '/tmp/tmpm1m1z_ux/OAS2_RAW_PART1/OAS2_0044_MR3/RAW'},
#  'OAS2_0045': {'1': '/tmp/tmpm1m1z_ux/OAS2_RAW_PART1/OAS2_0045_MR1/RAW',
#   '2': '/tmp/tmpm1m1z_ux/OAS2_RAW_PART1/OAS2_0045_MR2/RAW'},
#  'OAS2_0046': {'1': '/tmp/tmpm1m1z_ux/OAS2_RAW_PART1/OAS2_0046_MR1/RAW',
#   '2': '/tmp/tmpm1m1z_ux/OAS2_RAW_PART1/OAS2_0046_MR2/RAW'},
#  'OAS2_0047': {'1': '/tmp/tmpm1m1z_ux/OAS2_RAW_PART1/OAS2_0047_MR1/RAW',
#   '2': '/tmp/tmpm1m1z_ux/OAS2_RAW_PART1/OAS2_0047_MR2/RAW'},
#  'OAS2_0048': {'1': '/tmp/tmpm1m1z_ux/OAS2_RAW_PART1/OAS2_0048_MR1/RAW',
#   '2': '/tmp/tmpm1m1z_ux/OAS2_RAW_PART1/OAS2_0048_MR2/RAW',
#   '3': '/tmp/tmpm1m1z_ux/OAS2_RAW_PART1/OAS2_0048_MR3/RAW',
#   '4': '/tmp/tmpm1m1z_ux/OAS2_RAW_PART1/OAS2_0048_MR4/RAW',
#   '5': '/tmp/tmpm1m1z_ux/OAS2_RAW_PART1/OAS2_0048_MR5/RAW'},
#  'OAS2_0049': {'1': '/tmp/tmpm1m1z_ux/OAS2_RAW_PART1/OAS2_0049_MR1/RAW',
#   '2': '/tmp/tmpm1m1z_ux/OAS2_RAW_PART1/OAS2_0049_MR2/RAW',
#   '3': '/tmp/tmpm1m1z_ux/OAS2_RAW_PART1/OAS2_0049_MR3/RAW'},
#  'OAS2_0050': {'1': '/tmp/tmpm1m1z_ux/OAS2_RAW_PART1/OAS2_0050_MR1/RAW',
#   '2': '/tmp/tmpm1m1z_ux/OAS2_RAW_PART1/OAS2_0050_MR2/RAW'},
#  'OAS2_0051': {'1': '/tmp/tmpm1m1z_ux/OAS2_RAW_PART1/OAS2_0051_MR1/RAW',
#   '2': '/tmp/tmpm1m1z_ux/OAS2_RAW_PART1/OAS2_0051_MR2/RAW',
#   '3': '/tmp/tmpm1m1z_ux/OAS2_RAW_PART1/OAS2_0051_MR3/RAW'},
#  'OAS2_0052': {'1': '/tmp/tmpm1m1z_ux/OAS2_RAW_PART1/OAS2_0052_MR1/RAW',
#   '2': '/tmp/tmpm1m1z_ux/OAS2_RAW_PART1/OAS2_0052_MR2/RAW'},
#  'OAS2_0053': {'1': '/tmp/tmpm1m1z_ux/OAS2_RAW_PART1/OAS2_0053_MR1/RAW',
#   '2': '/tmp/tmpm1m1z_ux/OAS2_RAW_PART1/OAS2_0053_MR2/RAW'},
#  'OAS2_0054': {'1': '/tmp/tmpm1m1z_ux/OAS2_RAW_PART1/OAS2_0054_MR1/RAW',
#   '2': '/tmp/tmpm1m1z_ux/OAS2_RAW_PART1/OAS2_0054_MR2/RAW'},
#  'OAS2_0055': {'1': '/tmp/tmpm1m1z_ux/OAS2_RAW_PART1/OAS2_0055_MR1/RAW',
#   '2': '/tmp/tmpm1m1z_ux/OAS2_RAW_PART1/OAS2_0055_MR2/RAW'},
#  'OAS2_0056': {'1': '/tmp/tmpm1m1z_ux/OAS2_RAW_PART1/OAS2_